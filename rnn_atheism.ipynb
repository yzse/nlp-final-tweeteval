# %%
import os
import re

import numpy as np
import tensorflow as tf

np.random.seed(1)
tf.random.set_seed(44)
tf.config.experimental.enable_op_determinism()

import pandas as pd
import keras
# from tqdm import tqdm
from tqdm import tqdm_notebook as tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight
from sklearn.metrics import f1_score, classification_report, log_loss

from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
from keras.utils import pad_sequences
from keras.utils import to_categorical

from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, SpatialDropout1D, Bidirectional, Flatten
from keras.layers import Dropout, Conv1D, GlobalMaxPool1D, GRU, GlobalAvgPool1D
from keras.optimizers import Adam, RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping

import keras.metrics as km

# %%
train = pd.read_csv('cleaned_df/stance_atheism_train_cleaned.csv')
test = pd.read_csv('cleaned_df/stance_atheism_test_cleaned.csv')
validation = pd.read_csv('cleaned_df/stance_atheism_validation_cleaned.csv')

# %%
# Mapping of common contractions
CONTRACTION_MAPPING1 = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", 
                       "couldn't": "could not", "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
                       "hasn't": "has not", "haven't": "have not", "he'd": "he would","he'll": "he will", "he's": "he is", 
                       "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",  "I'd": "I would", 
                       "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", 
                       "i'd": "i would", "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", 
                       "i've": "i have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", 
                       "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam", "mayn't": "may not", 
                       "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have", 
                       "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have",
                       "o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", 
                       "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", 
                       "she'll": "she will", "she'll've": "she will have", "she's": "she is", "should've": "should have", 
                       "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as", 
                       "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", 
                       "there'd": "there would", "there'd've": "there would have", "there's": "there is", "here's": "here is",
                       "they'd": "they would", "they'd've": "they would have", "they'll": "they will", "they'll've": 
                       "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", 
                       "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                       "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", 
                       "what'll've": "what will have", "what're": "what are",  "what's": "what is", "what've": "what have", 
                       "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is", 
                       "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", 
                       "who've": "who have", "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", 
                       "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", 
                       "y'all": "you all", "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are",
                       "y'all've": "you all have","you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                       "you'll've": "you will have", "you're": "you are", "you've": "you have", "It's": 'It is', "Can't": 'Can not',
                      }

# %%
# Mapping of common contractions, no apostrophes 
CONTRACTION_MAPPING2 = {"aint": "is not", "arent": "are not","cant": "cannot", "'cause": "because", "cos": "because", "couldve": "could have", 
                       "couldnt": "could not", "didnt": "did not",  "doesnt": "does not", "dont": "do not", "hadnt": "had not", 
                       "hasnt": "has not", "havent": "have not", "hed": "he would","hell": "he will", "hes": "he is", 
                       "howd": "how did", "how'd'y": "how do you", "howll": "how will", "hows": "how is",  "Id": "I would", 
                       "Idve": "I would have", "Ill": "I will", "Illve": "I will have","Im": "I am", "Ive": "I have", 
                       "id": "i would", "idve": "i would have", "ill": "i will",  "illve": "i will have", "im": "i am", 
                       "ive": "i have", "isnt": "is not", "itd": "it would", "itdve": "it would have", "itll": "it will", 
                       "itllve": "it will have","its": "it is", "lets": "let us", "maam": "madam", "maynt": "may not", 
                       "mightve": "might have","mightnt": "might not","mightntve": "might not have", "mustve": "must have", 
                       "mustnt": "must not", "mustntve": "must not have", "neednt": "need not", "needntve": "need not have",
                       "o'clock": "of the clock", "oughtnt": "ought not", "oughtntve": "ought not have", "shant": "shall not", 
                       "shant": "shall not", "shantve": "shall not have", "shed": "she would", "shedve": "she would have", 
                       "shell": "she will", "shellve": "she will have", "shes": "she is", "shouldve": "should have", 
                       "shouldnt": "should not", "shouldntve": "should not have", "sove": "so have", 
                       "thatd": "that would", "thatdve": "that would have", "thats": "that is", 
                       "thered": "there would", "theredve": "there would have", "theres": "there is", "heres": "here is",
                       "theyd": "they would", "theydve": "they would have", "theyll": "they will", "theyllve": 
                       "they will have", "theyre": "they are", "theyve": "they have",  "wasnt": "was not", 
                       "wed": "we would", "wedve": "we would have", "wellve": "we will have", 
                        "weve": "we have", "werent": "were not", "whatll": "what will", "hell": "he will",
                       "whatllve": "what will have", "whatre": "what are",  "whats": "what is", "whatve": "what have", 
                       "whens": "when is", "whenve": "when have", "whered": "where did", "wheres": "where is", 
                       "whereve": "where have", "wholl": "who will", "whollve": "who will have", "whos": "who is", 
                       "whove": "who have", "whys": "why is", "whyve": "why have", "willve": "will have", "wont": "will not", 
                       "wontve": "will not have", "wouldve": "would have", "wouldnt": "would not", "wouldntve": "would not have", 
                       "yall": "you all", "yalld": "you all would","yalldve": "you all would have",
                       "youd": "you would", "youdve": "you would have", "youll": "you will", 
                       "youllve": "you will have", "youre": "you are", "youve": "you have", "Its": 'It is', "Cant": 'Can not',
                      }

# %% [markdown]
# Determine optimal batch size

# %%
#training constants
MAX_SEQ_LEN = train['text'].apply(lambda x : len(x.split(' '))).quantile(0.95)
DEFAULT_BATCH_SIZE = 128

print(MAX_SEQ_LEN)
# Out:
# 19.0

# %% [markdown]
# Data cleaning

# %%
def clean_text(text, mapping):
    replace_white_space = ["\n"]
    for s in replace_white_space:
        text = text.replace(s, " ")
    replace_punctuation = ["’", "‘", "´", "`", "\'", r"\'"]
    for s in replace_punctuation:
        text = text.replace(s, "'")

    mapped_string = []
    for t in text.split(" "):
        if t in mapping:
            mapped_string.append(mapping[t])
        elif t.lower() in mapping:
            mapped_string.append(mapping[t.lower()])
        else:
            mapped_string.append(t)
    return ' '.join(mapped_string)

# %%
# Get tweets from Data frame and convert to list of "texts" scrubbing based on clean_text function
# CONTRACTION_MAPPING is a map of common contractions(e.g don't => do not)
train_text_vec = [clean_text(text, CONTRACTION_MAPPING1) for text in train['text'].values]
test_text_vec = [clean_text(text, CONTRACTION_MAPPING1) for text in test['text'].values]
validation_vec = [clean_text(text, CONTRACTION_MAPPING1) for text in validation['text'].values]

train_text_vec = [clean_text(text, CONTRACTION_MAPPING2) for text in train['text'].values]
test_text_vec = [clean_text(text, CONTRACTION_MAPPING2) for text in test['text'].values]
validation_vec = [clean_text(text, CONTRACTION_MAPPING2) for text in validation['text'].values]

# %% [markdown]
# Tokenizing and padding

# %%
# tokenize the sentences
tokenizer = Tokenizer(lower=False)
tokenizer.fit_on_texts(train_text_vec)
train_text_vec = tokenizer.texts_to_sequences(train_text_vec)
test_text_vec = tokenizer.texts_to_sequences(test_text_vec)
validation_vec = tokenizer.texts_to_sequences(validation_vec)

# pad the sequences
train_text_vec = pad_sequences(train_text_vec, maxlen=MAX_SEQ_LEN)
test_text_vec = pad_sequences(test_text_vec, maxlen=MAX_SEQ_LEN)
validation_vec = pad_sequences(validation_vec, maxlen=MAX_SEQ_LEN)

print('Number of Tokens:', len(tokenizer.word_index))
print('Max Token Index:', train_text_vec.max(), "\n")

print('Sample Tweet Before Processing:', train['text'].values[73])
print('Sample Tweet After Processing:', tokenizer.sequences_to_texts([train_text_vec[73]]), '\n')

print('What the model will interpret:', train_text_vec[0].tolist())
# Out:
# Number of Tokens: 2086
# Max Token Index: 2086
#
# Sample Tweet Before Processing: save your people lord and bless those who are yours their shepherd and take care them forever psalm gnt
# Sample Tweet After Processing: ['your people lord and bless those who are yours their shepherd and take care them forever psalm gnt']
#
# What the model will interpret: [0, 0, 0, 0, 0, 0, 0, 0, 0, 147, 227, 4, 227, 78, 79, 3, 1, 691]

# %%
# One Hot Encode Y values:
encoder = LabelEncoder()

y_train = encoder.fit_transform(train['label'].values)
y_train = to_categorical(y_train) 

y_test = encoder.fit_transform(test['label'].values)
y_test = to_categorical(y_test) 

y_validation = encoder.fit_transform(validation['label'].values)
y_validation = to_categorical(y_validation)

# %%
# get an idea of the distribution of the text values
from collections import Counter
ctr = Counter(train['label'].values)
print('Distribution of Classes:', ctr)

# get class weights for the training data, this will be used data
y_train_int = np.argmax(y_train,axis=1)

cws = class_weight.compute_class_weight(class_weight = "balanced", 
                                        classes = np.unique(y_train_int),
                                        y = y_train_int)
cws = {i : cws[i] for i in range(3)}
print(cws)
# Out:
# Distribution of Classes: Counter({1: 272, 0: 105, 2: 83})
# {0: 1.4603174603174602, 1: 0.5637254901960784, 2: 1.8473895582329318}

# %% [markdown]
# ## Building a neural network model

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

optimizer = RMSprop(learning_rate=0.01)
np.set_printoptions(precision=4)

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    target_names = ['none', 'against', 'favour']
    _cm = confusion_matrix(y_true, y_pred)
    
    print(classification_report(y_true, y_pred, target_names=target_names))

        
    def _build_matrix(fig, ax, cm, normalize = False):
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'
        
        if normalize:
            cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

        im = ax.imshow(cm, cmap=cmap)
#         fig.colorbar(im, ax=ax)
        ax.set(xticks=np.arange(cm.shape[1]),
               yticks=np.arange(cm.shape[0]),
               # ... and label them with the respective list entries
               xticklabels=target_names, 
               yticklabels=target_names,
               title=title,
               ylabel='True label',
               xlabel='Predicted label')

        # Rotate the tick labels and set their alignment.
        plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

        # Loop over data dimensions and create text annotations.
        fmt = '.2f' if normalize else 'd'
        thresh = cm.max() / 2.
        for i in range(cm.shape[0]):
            for j in range(cm.shape[1]):
                ax.text(j, i, format(cm[i, j], fmt),
                        ha="center", va="center",
                        color="white" if cm[i, j] > thresh else "black")
        
    fig, [ax1, ax2] = plt.subplots(nrows = 1, ncols = 2, figsize=(8, 4))
    _build_matrix(fig, ax1, cm = _cm, normalize=False)
    _build_matrix(fig, ax2, cm = _cm, normalize=True)
    fig.tight_layout()

# %%
from sklearn.metrics import recall_score, precision_score

def threshold_search(y_true, y_proba, average = None):
    best_threshold = 0
    best_score = 0
    for threshold in [i * 0.01 for i in range(100)]:
        score = f1_score(y_true=y_true, y_pred=y_proba > threshold, average=average)
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'f1': best_score}
    return search_result


def train_model(model, 
          X_train, y_train, X_test, y_test, X_validation, y_validation,
          class_weights,
          checkpoint_path, 
          epcohs = 25, 
          batch_size = DEFAULT_BATCH_SIZE, 
           
          fit_verbose=2,
          print_summary = True
         ):
    m = model()
    if print_summary:
        print(m.summary())
    m.fit(
        X_train, 
        y_train, 
        validation_data=(X_validation, y_validation),  
        epochs=epcohs, 
        batch_size=batch_size,
        class_weight=class_weights,
         #saves the most accurate model, usually you would save the one with the lowest loss
        callbacks= [
            ModelCheckpoint(checkpoint_path, monitor='val_acc', verbose=1, save_best_only=True),
            EarlyStopping(patience = 2)
        ],
        verbose=fit_verbose
    ) 

    m.save_weights(checkpoint_path.format(epoch=0))

    print("\n\n****************************\n\n")
    print('Loading Best Model...')
    m.load_weights(checkpoint_path)
    predictions = m.predict(X_test, verbose=1)

    # recall = recall_score(y_test, predictions, average='weighted') * 100
    # precision = precision_score(y_test, predictions, average='weighted') * 100
    
    # print(f'Precision: {precision:.2f}')
    # print(f'Recall: {recall:.2f}')

    print('Validation Loss:', log_loss(y_test, predictions))
    print('Test Accuracy', (predictions.argmax(axis = 1) == y_test.argmax(axis = 1)).mean())
    print('F1 Score:', f1_score(y_test.argmax(axis = 1), predictions.argmax(axis = 1), average='weighted'))
    
    plot_confusion_matrix(y_test.argmax(axis = 1), predictions.argmax(axis = 1), classes=encoder.classes_)
    plt.show()   
     
    return m #returns best performing model

# %% [markdown]
# ### Simple LSTM

# %%
def model_1():
    """
    Using a Simple LSTM. 
    """
    model = Sequential()
    model.add(Embedding(input_dim = (len(tokenizer.word_counts) + 1), output_dim = 128, input_length = MAX_SEQ_LEN))
    model.add(LSTM(128))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(3, activation='softmax'))
    model.compile(loss='categorical_crossentropy', 
                  optimizer=optimizer, 
                   metrics=['accuracy', km.Precision(), km.Recall()])
    return model

m1 = train_model(model_1, 
           train_text_vec,
           y_train,
           test_text_vec,
           y_test,
           validation_vec,
           y_validation,
           class_weights=cws,
           checkpoint_path='saved_models/atheism/model_1a.h5',
          )
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 18, 128)           267136
#
#  lstm (LSTM)                 (None, 128)               131584
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 407,171
# Trainable params: 407,171
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 7s - loss: 1.1872 - accuracy: 0.4087 - precision: 0.4535 - recall: 0.0848 - val_loss: 1.3094 - val_accuracy: 0.5769 - val_precision: 0.5957 - val_recall: 0.5385 - 7s/epoch - 2s/step
# Epoch 2/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 0s - loss: 0.7790 - accuracy: 0.7304 - precision: 0.8065 - recall: 0.5978 - val_loss: 3.2237 - val_accuracy: 0.2308 - val_precision: 0.2353 - val_recall: 0.2308 - 265ms/epoch - 66ms/step
# Epoch 3/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 0s - loss: 0.4146 - accuracy: 0.8696 - precision: 0.8818 - recall: 0.8435 - val_loss: 1.4297 - val_accuracy: 0.5385 - val_precision: 0.5714 - val_recall: 0.5385 - 272ms/epoch - 68ms/step
#
#
# ****************************
#
#
# Loading Best Model...
# 7/7 [==============================] - 1s 7ms/step
# Validation Loss: 1.265602832650488
# Test Accuracy 0.6045454545454545
# F1 Score: 0.6353888535706715
#               precision    recall  f1-score   support
#
#         none       0.42      0.57      0.48        28
#      against       0.83      0.66      0.73       160
#       favour       0.21      0.38      0.27        32
#
#     accuracy                           0.60       220
#    macro avg       0.49      0.53      0.50       220
# weighted avg       0.69      0.60      0.64       220

# %% [markdown]
# ### Bi-Directional LSTM

# %%
def model_1b():
    """
    Using a Bidiretional LSTM. 
    """
    model = Sequential()
    model.add(Embedding(input_dim = (len(tokenizer.word_counts) + 1), output_dim = 128, input_length = MAX_SEQ_LEN))
    model.add(SpatialDropout1D(0.3))
    model.add(Bidirectional(LSTM(128, dropout=0.25, recurrent_dropout=0.25)))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(3, activation='softmax'))
    model.compile(loss='categorical_crossentropy', 
                  optimizer=optimizer, 
                  metrics=['accuracy', km.Precision(), km.Recall()])
    return model

m1b = train_model(model_1b, 
           train_text_vec,
           y_train,
           test_text_vec,
           y_test,
           validation_vec,
           y_validation,
           checkpoint_path='saved_models/atheism/model_1b.h5',
           class_weights=cws,
           print_summary = True
          )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 18, 128)           267136
#
#  spatial_dropout1d (SpatialD  (None, 18, 128)          0
#  ropout1D)
#
#  bidirectional (Bidirectiona  (None, 256)              263168
#  l)
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_3 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 546,947
# Trainable params: 546,947
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 14s - loss: 1.6563 - accuracy: 0.3478 - precision_1: 0.3407 - recall_1: 0.1674 - val_loss: 1.7099 - val_accuracy: 0.5962 - val_precision_1: 0.5962 - val_recall_1: 0.5962 - 14s/epoch - 4s/step
# Epoch 2/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 1.7314 - accuracy: 0.4674 - precision_1: 0.4513 - recall_1: 0.3022 - val_loss: 1.1085 - val_accuracy: 0.3654 - val_precision_1: 0.4000 - val_recall_1: 0.1154 - 579ms/epoch - 145ms/step
# Epoch 3/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 0.9069 - accuracy: 0.7174 - precision_1: 0.8051 - recall_1: 0.4761 - val_loss: 1.3993 - val_accuracy: 0.1731 - val_precision_1: 0.1538 - val_recall_1: 0.0769 - 693ms/epoch - 173ms/step
# Epoch 4/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 0.5877 - accuracy: 0.7261 - precision_1: 0.8195 - recall_1: 0.6217 - val_loss: 3.0939 - val_accuracy: 0.2692 - val_precision_1: 0.3182 - val_recall_1: 0.2692 - 739ms/epoch - 185ms/step
#
#
# ****************************
#
#
# Loading Best Model...
# 7/7 [==============================] - 1s 7ms/step
# Validation Loss: 3.4815832745331465
# Test Accuracy 0.31363636363636366
# F1 Score: 0.332944348122388
#               precision    recall  f1-score   support
#
#         none       0.17      1.00      0.29        28
#      against       0.97      0.24      0.39       160
#       favour       0.13      0.06      0.09        32
#
#     accuracy                           0.31       220
#    macro avg       0.43      0.44      0.26       220
# weighted avg       0.75      0.31      0.33       220

# %% [markdown]
# ### Including convolutions

# %%
def model_1c():
    """
    Adding dropout to reduce overfitting using a bidiretional LSTM
    """
    model = Sequential()
    model.add(Embedding(input_dim = (len(tokenizer.word_counts) + 1), output_dim = 128, input_length = MAX_SEQ_LEN))
    model.add(SpatialDropout1D(0.3))
    model.add(Bidirectional(LSTM(128, dropout=0.25, recurrent_dropout=0.25, return_sequences=True)))
    model.add(Conv1D(64, 4))
#     model.add(Flatten())
    model.add(GlobalMaxPool1D())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(3, activation='softmax'))
    model.compile(loss='categorical_crossentropy', 
                  optimizer=optimizer, 
                  metrics=['accuracy', km.Precision(), km.Recall()])
#     print(model.summary())
    return model


m1c = train_model(model_1c, 
           train_text_vec,
           y_train,
           test_text_vec,
           y_test,
           validation_vec,
           y_validation,
           checkpoint_path='saved_models/atheism/model_1c.h5',
           class_weights=cws,
           print_summary = True
          )
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 18, 128)           267136
#
#  spatial_dropout1d_1 (Spatia  (None, 18, 128)          0
#  lDropout1D)
#
#  bidirectional_1 (Bidirectio  (None, 18, 256)          263168
#  nal)
#
#  conv1d (Conv1D)             (None, 15, 64)            65600
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 600,259
# Trainable params: 600,259
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 9s - loss: 2.3641 - accuracy: 0.4304 - precision_2: 0.3322 - recall_2: 0.2152 - val_loss: 1.2104 - val_accuracy: 0.4231 - val_precision_2: 0.2778 - val_recall_2: 0.0962 - 9s/epoch - 2s/step
# Epoch 2/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 5.8960 - accuracy: 0.3957 - precision_2: 0.3840 - recall_2: 0.3348 - val_loss: 1.0437 - val_accuracy: 0.5577 - val_precision_2: 0.6389 - val_recall_2: 0.4423 - 712ms/epoch - 178ms/step
# Epoch 3/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 2.0170 - accuracy: 0.4370 - precision_2: 0.4545 - recall_2: 0.3587 - val_loss: 1.2033 - val_accuracy: 0.1923 - val_precision_2: 0.2143 - val_recall_2: 0.1154 - 651ms/epoch - 163ms/step
# Epoch 4/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 0.8968 - accuracy: 0.4717 - precision_2: 0.5575 - recall_2: 0.3478 - val_loss: 1.6725 - val_accuracy: 0.2308 - val_precision_2: 0.2340 - val_recall_2: 0.2115 - 640ms/epoch - 160ms/step
#
#
# ****************************
#
#
# Loading Best Model...
# 7/7 [==============================] - 1s 7ms/step
# Validation Loss: 1.7762579826553437
# Test Accuracy 0.1409090909090909
# F1 Score: 0.051292463147490946
#               precision    recall  f1-score   support
#
#         none       0.15      1.00      0.25        28
#      against       1.00      0.01      0.01       160
#       favour       0.07      0.06      0.07        32
#
#     accuracy                           0.14       220
#    macro avg       0.41      0.36      0.11       220
# weighted avg       0.76      0.14      0.05       220

# %% [markdown]
# Including dropout

# %%
def model_1d():
    """
    Experimenting with other specifications
    """
    model = Sequential()
    model.add(Embedding(input_dim = (len(tokenizer.word_counts) + 1), output_dim = 128, input_length = MAX_SEQ_LEN))
    model.add(Bidirectional(LSTM(256, return_sequences=True, recurrent_dropout=0.2, dropout=0.2), 'concat'))
    model.add(Dropout(0.4))
    model.add(LSTM(128, return_sequences=True, recurrent_dropout=0.2, dropout=0.2))
    model.add(Dropout(0.4))
    model.add(LSTM(64, return_sequences=False, recurrent_dropout=0.2, dropout=0.2))
    model.add(Dropout(0.2))
    model.add(Dense(64, activation='sigmoid'))
    model.add(Dropout(0.2))
    model.add(Dense(3, activation='softmax'))
    model.compile(loss ='categorical_crossentropy', 
                  optimizer = optimizer, 
                  metrics = ['accuracy', km.Precision(), km.Recall()])
    return model


m1d = train_model(model_1d, 
           train_text_vec,
           y_train,
           test_text_vec,
           y_test,
           validation_vec,
           y_validation,
           checkpoint_path='saved_models/atheism/model_1d.h5',
           class_weights=cws,
           print_summary = True
          )
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 18, 128)           267136
#
#  bidirectional_2 (Bidirectio  (None, 18, 512)          788480
#  nal)
#
#  dropout_1 (Dropout)         (None, 18, 512)           0
#
#  lstm_4 (LSTM)               (None, 18, 128)           328192
#
#  dropout_2 (Dropout)         (None, 18, 128)           0
#
#  lstm_5 (LSTM)               (None, 64)                49408
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 1,437,571
# Trainable params: 1,437,571
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 24s - loss: 1.4742 - accuracy: 0.2957 - precision_3: 0.2829 - recall_3: 0.2196 - val_loss: 1.7067 - val_accuracy: 0.1731 - val_precision_3: 0.1731 - val_recall_3: 0.1731 - 24s/epoch - 6s/step
# Epoch 2/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 3s - loss: 1.2784 - accuracy: 0.2935 - precision_3: 0.2885 - recall_3: 0.1957 - val_loss: 1.0990 - val_accuracy: 0.2308 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - 3s/epoch - 872ms/step
# Epoch 3/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 3s - loss: 1.1379 - accuracy: 0.2848 - precision_3: 0.3117 - recall_3: 0.0522 - val_loss: 1.0721 - val_accuracy: 0.5962 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - 3s/epoch - 825ms/step
# Epoch 4/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 3s - loss: 1.1728 - accuracy: 0.2935 - precision_3: 0.3443 - recall_3: 0.0457 - val_loss: 1.0963 - val_accuracy: 0.2308 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - 3s/epoch - 792ms/step
# Epoch 5/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 3s - loss: 1.1231 - accuracy: 0.3457 - precision_3: 0.3415 - recall_3: 0.0304 - val_loss: 1.1168 - val_accuracy: 0.1731 - val_precision_3: 0.0000e+00 - val_recall_3: 0.0000e+00 - 3s/epoch - 761ms/step
#
#
# ****************************
#
#
# Loading Best Model...
# 7/7 [==============================] - 2s 37ms/step
# Validation Loss: 1.1244377759369937
# Test Accuracy 0.14545454545454545
# F1 Score: 0.03694083694083694
#               precision    recall  f1-score   support
#
#         none       0.00      0.00      0.00        28
#      against       0.00      0.00      0.00       160
#       favour       0.15      1.00      0.25        32
#
#     accuracy                           0.15       220
#    macro avg       0.05      0.33      0.08       220
# weighted avg       0.02      0.15      0.04       220
# c:\Users\herre\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\herre\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\herre\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Using transfer learning

# %%
import gensim.downloader as api

tw25_model = api.load("glove-twitter-25")
tw100_model = api.load("glove-twitter-100")

# %%
word_index = tokenizer.word_index

def get_embeddings_matrix(embedding_model, word_index):

    embedding_dim = embedding_model.vector_size

    # Create the embedding matrix for vocabulary
    embedding_matrix = np.zeros(((len(tokenizer.word_counts) + 1), embedding_dim))
    for word, i in word_index.items():
        if word in embedding_model.key_to_index:
            embedding_matrix[i] = embedding_model.get_vector(word)
    
    return embedding_matrix

# %%
def model_2(embed_matrix):
    """
    Extends model_1 with a glove embedding
    """
    model = Sequential()
    model.add(Embedding(input_dim = embed_matrix.shape[0], 
                        output_dim = embed_matrix.shape[1], 
                        input_length = MAX_SEQ_LEN,  
                        weights=[embed_matrix], 
                        trainable=False))
    model.add(SpatialDropout1D(0.3))
    model.add(Bidirectional(LSTM(128, dropout=0.25, recurrent_dropout=0.25, return_sequences=True)))
    model.add(Conv1D(64, 4))
#     model.add(Flatten())
    model.add(GlobalMaxPool1D())
    model.add(Dense(64, activation='relu'))
    model.add(Dense(3, activation='softmax'))
    model.compile(loss='categorical_crossentropy', 
                  optimizer=optimizer, 
                   metrics=['accuracy', km.Precision(), km.Recall()])
    return model

# %% [markdown]
# #### Glove-twitter-25

# %%
tw25_embed_matrix = get_embeddings_matrix(tw25_model, word_index)

m2_tw25 = train_model(lambda : model_2(tw25_embed_matrix), 
           train_text_vec,
           y_train,
           test_text_vec,
           y_test,
           validation_vec,
           y_validation,
           checkpoint_path='saved_models/atheism/tw25_model.h5',
           class_weights=cws,
           fit_verbose = 2,
           print_summary = False
           )
# Out:
# Epoch 1/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 11s - loss: 7.6518 - accuracy: 0.3413 - precision_4: 0.3678 - recall_4: 0.2630 - val_loss: 14.1784 - val_accuracy: 0.1731 - val_precision_4: 0.1731 - val_recall_4: 0.1731 - 11s/epoch - 3s/step
# Epoch 2/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 0s - loss: 4.7592 - accuracy: 0.2065 - precision_4: 0.1990 - recall_4: 0.1739 - val_loss: 1.0065 - val_accuracy: 0.5962 - val_precision_4: 0.6667 - val_recall_4: 0.0769 - 459ms/epoch - 115ms/step
# Epoch 3/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 1.1826 - accuracy: 0.4196 - precision_4: 0.3846 - recall_4: 0.1304 - val_loss: 1.0495 - val_accuracy: 0.5192 - val_precision_4: 1.0000 - val_recall_4: 0.0192 - 665ms/epoch - 166ms/step
# Epoch 4/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 0s - loss: 1.0936 - accuracy: 0.4543 - precision_4: 0.8235 - recall_4: 0.0609 - val_loss: 1.1602 - val_accuracy: 0.2115 - val_precision_4: 0.0000e+00 - val_recall_4: 0.0000e+00 - 448ms/epoch - 112ms/step
#
#
# ****************************
#
#
# Loading Best Model...
# 7/7 [==============================] - 1s 8ms/step
# Validation Loss: 1.2180576161904768
# Test Accuracy 0.19090909090909092
# F1 Score: 0.1375774253418455
#               precision    recall  f1-score   support
#
#         none       0.25      0.04      0.06        28
#      against       0.85      0.07      0.13       160
#       favour       0.15      0.94      0.26        32
#
#     accuracy                           0.19       220
#    macro avg       0.41      0.35      0.15       220
# weighted avg       0.67      0.19      0.14       220

# %% [markdown]
# #### Glove-twitter-100

# %%
tw100_embed_matrix = get_embeddings_matrix(tw100_model, word_index)

m2_tw100 = train_model(lambda : model_2(tw100_embed_matrix), 
           train_text_vec,
           y_train,
           test_text_vec,
           y_test,
           validation_vec,
           y_validation,
           checkpoint_path='saved_models/atheism/tw100_model.h5',
           class_weights=cws,
           fit_verbose = 2,
           print_summary = False
           )
# Out:
# Epoch 1/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 12s - loss: 3.4777 - accuracy: 0.3609 - precision_5: 0.4164 - recall_5: 0.2978 - val_loss: 10.7746 - val_accuracy: 0.2308 - val_precision_5: 0.2308 - val_recall_5: 0.2308 - 12s/epoch - 3s/step
# Epoch 2/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 3.2735 - accuracy: 0.3087 - precision_5: 0.2884 - recall_5: 0.2326 - val_loss: 1.0508 - val_accuracy: 0.4038 - val_precision_5: 0.3000 - val_recall_5: 0.0577 - 702ms/epoch - 176ms/step
# Epoch 3/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 1.1120 - accuracy: 0.4500 - precision_5: 0.5535 - recall_5: 0.3261 - val_loss: 1.0446 - val_accuracy: 0.2692 - val_precision_5: 0.7143 - val_recall_5: 0.0962 - 660ms/epoch - 165ms/step
# Epoch 4/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 0.8869 - accuracy: 0.5957 - precision_5: 0.7189 - recall_5: 0.3891 - val_loss: 0.7768 - val_accuracy: 0.6731 - val_precision_5: 0.7273 - val_recall_5: 0.6154 - 687ms/epoch - 172ms/step
# Epoch 5/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 1.0613 - accuracy: 0.5609 - precision_5: 0.6124 - recall_5: 0.5152 - val_loss: 1.3163 - val_accuracy: 0.1731 - val_precision_5: 0.1765 - val_recall_5: 0.1731 - 625ms/epoch - 156ms/step
# Epoch 6/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 0.9019 - accuracy: 0.5957 - precision_5: 0.6266 - recall_5: 0.4196 - val_loss: 0.8486 - val_accuracy: 0.7500 - val_precision_5: 0.7917 - val_recall_5: 0.3654 - 613ms/epoch - 153ms/step
#
#
# ****************************
#
#
# Loading Best Model...
# 7/7 [==============================] - 1s 9ms/step
# Validation Loss: 0.9020290889523246
# Test Accuracy 0.6727272727272727
# F1 Score: 0.6979748706577976
#               precision    recall  f1-score   support
#
#         none       0.43      0.64      0.51        28
#      against       0.89      0.71      0.79       160
#       favour       0.32      0.50      0.39        32
#
#     accuracy                           0.67       220
#    macro avg       0.55      0.62      0.57       220
# weighted avg       0.75      0.67      0.70       220

# %% [markdown]
# #### Stacked

# %%
m2_tw_stacked = train_model(lambda : model_2(np.hstack((tw25_embed_matrix, tw100_embed_matrix))), 
           train_text_vec,
           y_train,
           test_text_vec,
           y_test,
           validation_vec,
           y_validation,
           checkpoint_path='saved_models/atheism/stack_embed_model.h5',
           class_weights=cws,
           fit_verbose = 2,
           print_summary = False
           )
# Out:
# Epoch 1/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 8s - loss: 6.4857 - accuracy: 0.4457 - precision_6: 0.4813 - recall_6: 0.3913 - val_loss: 3.6453 - val_accuracy: 0.2308 - val_precision_6: 0.2308 - val_recall_6: 0.2308 - 8s/epoch - 2s/step
# Epoch 2/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 3.4511 - accuracy: 0.2826 - precision_6: 0.2832 - recall_6: 0.2783 - val_loss: 2.1304 - val_accuracy: 0.1731 - val_precision_6: 0.1731 - val_recall_6: 0.1731 - 565ms/epoch - 141ms/step
# Epoch 3/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 1.3206 - accuracy: 0.2652 - precision_6: 0.2123 - recall_6: 0.0826 - val_loss: 1.1383 - val_accuracy: 0.2115 - val_precision_6: 1.0000 - val_recall_6: 0.0385 - 696ms/epoch - 174ms/step
# Epoch 4/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 0.9832 - accuracy: 0.4848 - precision_6: 0.8454 - recall_6: 0.1783 - val_loss: 1.0095 - val_accuracy: 0.5577 - val_precision_6: 0.6538 - val_recall_6: 0.3269 - 751ms/epoch - 188ms/step
# Epoch 5/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 0.8722 - accuracy: 0.6565 - precision_6: 0.7829 - recall_6: 0.4391 - val_loss: 1.2699 - val_accuracy: 0.3077 - val_precision_6: 0.3824 - val_recall_6: 0.2500 - 625ms/epoch - 156ms/step
# Epoch 6/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 1.0129 - accuracy: 0.5348 - precision_6: 0.5963 - recall_6: 0.4174 - val_loss: 1.0041 - val_accuracy: 0.5769 - val_precision_6: 0.8261 - val_recall_6: 0.3654 - 646ms/epoch - 161ms/step
# Epoch 7/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 0.9076 - accuracy: 0.6152 - precision_6: 0.7540 - recall_6: 0.4130 - val_loss: 1.1163 - val_accuracy: 0.3077 - val_precision_6: 0.3571 - val_recall_6: 0.1923 - 764ms/epoch - 191ms/step
# Epoch 8/25
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
# 4/4 - 1s - loss: 0.7879 - accuracy: 0.6565 - precision_6: 0.7546 - recall_6: 0.5348 - val_loss: 1.4756 - val_accuracy: 0.2885 - val_precision_6: 0.2857 - val_recall_6: 0.2308 - 783ms/epoch - 196ms/step
#
#
# ****************************
#
#
# Loading Best Model...
# 7/7 [==============================] - 1s 27ms/step
# Validation Loss: 1.5907558952542868
# Test Accuracy 0.2409090909090909
# F1 Score: 0.20259252640103817
#               precision    recall  f1-score   support
#
#         none       0.19      1.00      0.32        28
#      against       1.00      0.10      0.18       160
#       favour       0.16      0.28      0.21        32
#
#     accuracy                           0.24       220
#    macro avg       0.45      0.46      0.24       220
# weighted avg       0.77      0.24      0.20       220
